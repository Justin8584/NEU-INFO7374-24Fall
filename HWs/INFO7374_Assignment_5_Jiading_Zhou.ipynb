# %% [markdown]
# Assignment 5 (50 points)
#
# Agents are an emerging field thats use reflection, tools, planning, and multi agent collaboration
#
# In this assignment, we will build a research agent. We will use serverless LLM endpoints. To get started, you create an account with Together AI or Anthropic. They should provide you with a few dollars worth of credits that should be enough to complete the assignment. You are free to choose any other provider such as OpenAI, Mistral, Fireworks, or Groq. I encourage you to play around with different models to get a feel for how they work. For this assignment, the API usage cost should be around a couple dollars. Depending on the model you choose and how many attempts you use, it may be a couple cents. For OpenAI, Anthropic, and Mistral, double check what model you are using. The flagship models are significantly more expensive than the smaller models (pricing between models varies by 50x). For the purposes of this assignment, it is sufficient to use the smallest/cheapest models.
#
# TogetherAI, Fireworks, and Groq run open source models. For these, it’s better to run the mid-large tier models. Mixtral is a good place to start. It’s good to play around with different models.
#
# Many providers are able to use OpenAI's client library, but some do not (like Anthropic). Use whatever makes sense.
#
# You can run this on Colab with a CPU, or locally and submit the Jupyter notebook as your submission. Since we are using third party providers for the LLMs, we will not load the model locally. If you run on Colab, take special care to not leak your API key. Here’s an example of how to properly use secrets in Colab.
#
# Research Agent
# Build an LLM-based research agent that can take a research topic, find relevant information, and generate a short summary (~1 paragraph) on the given topic.
#
# Tools to Implement (20 points, 4 points each):
# 1. Topic Breakdown Tool: Create a tool that takes a broad research topic and breaks it down into smaller, more focused subtopics or subqueries. You can use an LLM to generate these subtopics based on the main topic.
#
# 2. Query Expansion Tool: Develop a tool to expand the subqueries generated by the Topic Breakdown Tool. The tool should generate related keywords, synonyms, and phrases to enhance the search results.
#
# 3. Search Tool: Create a wrapper around the You API or Brave Search API, Serper.dev. Please note that the free tier is 1000 queries/month. Consider creating a mock while developing, and switch to actually call the You API once the agent is more stable. Additionally, consider caching the search results.
#
# 4. Critique Tool: Create a tool that critiques the summary, and offers suggestions of how to improve and potentially other relevant topics to search for.
#
# 5. Summarizer Tool (optional): Create a tool that takes some input and summarizes its content using an LLM.
#
# Workflow (30 points)
# Implement an agent workflow that uses all of these tools. In the agent workflow, the agent should be provided with all the tools and it should decide which tool to use. For the individual tool implementations, if you use a call to an LLM you do not need to provide any tools.
#
# Sample Agent Workflow:
# 1. The agent receives a research topic from the user.
# 2. It uses the Topic Breakdown Tool to generate subtopics or subqueries.
# 3. The Query Expansion Tool expands the subqueries with related keywords and phrases.
# 4. The Search Tool uses the expanded queries and subqueries to gather relevant information from various sources.
# 5. The agent generates the summary incorporating the search results. (optional)
# 6. The agent critiques the summary, and improves the results. (optional)
# 7. The agent presents the final summary to the user.
#
# The sample workflow is the minimum implementation requirement. Feel free to add more tools, add loops in the workflow, etc.

# %%
# !nvidia-smi
# Out:
# Sun Dec  8 18:16:00 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   58C    P8              11W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
# !pip install --upgrade together
# Out:
# Requirement already satisfied: together in /usr/local/lib/python3.10/dist-packages (1.3.5)
# Requirement already satisfied: aiohttp<4.0.0,>=3.9.3 in /usr/local/lib/python3.10/dist-packages (from together) (3.11.9)
# Requirement already satisfied: click<9.0.0,>=8.1.7 in /usr/local/lib/python3.10/dist-packages (from together) (8.1.7)
# Requirement already satisfied: eval-type-backport<0.3.0,>=0.1.3 in /usr/local/lib/python3.10/dist-packages (from together) (0.2.0)
# Requirement already satisfied: filelock<4.0.0,>=3.13.1 in /usr/local/lib/python3.10/dist-packages (from together) (3.16.1)
# Requirement already satisfied: numpy>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from together) (1.26.4)
# Requirement already satisfied: pillow<11.0.0,>=10.3.0 in /usr/local/lib/python3.10/dist-packages (from together) (10.4.0)
# Requirement already satisfied: pyarrow>=10.0.1 in /usr/local/lib/python3.10/dist-packages (from together) (17.0.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.6.3 in /usr/local/lib/python3.10/dist-packages (from together) (2.10.3)
# Requirement already satisfied: requests<3.0.0,>=2.31.0 in /usr/local/lib/python3.10/dist-packages (from together) (2.32.3)
# Requirement already satisfied: rich<14.0.0,>=13.8.1 in /usr/local/lib/python3.10/dist-packages (from together) (13.9.4)
# Requirement already satisfied: tabulate<0.10.0,>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from together) (0.9.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.2 in /usr/local/lib/python3.10/dist-packages (from together) (4.66.6)
# Requirement already satisfied: typer<0.14,>=0.9 in /usr/local/lib/python3.10/dist-packages (from together) (0.13.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.9.3->together) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.9.3->together) (1.3.1)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.9.3->together) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.9.3->together) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.9.3->together) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.9.3->together) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.9.3->together) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.9.3->together) (1.18.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.6.3->together) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.6.3->together) (2.27.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.6.3->together) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.31.0->together) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.31.0->together) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.31.0->together) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.31.0->together) (2024.8.30)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich<14.0.0,>=13.8.1->together) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich<14.0.0,>=13.8.1->together) (2.18.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<0.14,>=0.9->together) (1.5.4)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=13.8.1->together) (0.1.2)

# %%
# !pip install openai
# !pip show openai
# Out:
# Requirement already satisfied: openai in /usr/local/lib/python3.10/dist-packages (1.54.5)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from openai) (0.28.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from openai) (0.8.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai) (2.10.3)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.6)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.10/dist-packages (from openai) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (2.27.1)
# Name: openai
# Version: 1.54.5
# Summary: The official Python library for the openai API
# Home-page: https://github.com/openai/openai-python
# Author:
# Author-email: OpenAI <support@openai.com>
# License: Apache-2.0
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: anyio, distro, httpx, jiter, pydantic, sniffio, tqdm, typing-extensions
# Required-by:

# %%
from openai import OpenAI
import os


from google.colab import userdata
Together_API_Token = userdata.get('Together_API_Token')
YOUR_API_KEY=userdata.get('YOUR_API_KEY')


import together
client = together.Client(api_key=Together_API_Token,base_url='https://api.together.xyz/v1',)

# %%
model_name = "meta-llama/Llama-3.3-70B-Instruct-Turbo"

# %%
def topic_breakdown_tool(research_topic):
      chat_completion = client.chat.completions.create(
        messages=[
          {
            "role": "system",
            "content": "You are an AI research assistant.",
          },
          {
            "role": "user",
            "content": f"Generate 4 subQUERIES based on the research topic: {research_topic}.",
          }
        ],
        model=model_name,
        temperature=0.9,
        max_tokens=256,
        top_k=40
      )
      subqueries=chat_completion.choices[0].message.content

      return subqueries

# %%
def query_expansion_tool(subqueries):
    conversation = [
        {"role": "system", "content": "You are an AI research assistant."},
        {"role": "user", "content": f"Generate 4 keywords, synonyms, and phrases for each of the subqueries:{subqueries} and should follow the following format: {{'Subquery':Subquery,'Keywords':keywords,'Synonyms':Synonyms,'Phrases':phrases}}"}
    ]
    # Request chat completions for generating keywords based on the conversation
    chat_completion = client.chat.completions.create(
        messages=conversation,
        model=model_name,
        temperature=0.9,
        max_tokens=512,
        top_k=40
    )

    # Extract keywords from the completion
    expanded_queries = chat_completion.choices[0].message.content
    return expanded_queries

# %%
import requests
from cachetools import TTLCache
from datetime import datetime, timedelta

cache = TTLCache(maxsize=100, ttl=3600)

def search_tool(query):

    if query in cache:
        print("Returning cached results for:", query)
        return cache[query]

    headers = {"X-API-Key": YOUR_API_KEY}
    params = {"query": query}
    response= requests.get(
        f"https://api.ydc-index.io/search?query={query}",
        params=params,
        headers=headers,
    ).json()

    cache[query] = response

    return response

# %%
def summary_tool(search_result):
    messages = [
        {"role": "system", "content": "You are an AI research assistant."},
        {"role": "user", "content": f"Provide Summary for the following search results generated:\n\n{search_result}."}
    ]
    response = client.chat.completions.create(
        model=model_name,
        messages=messages,
        max_tokens=500,
        stop=None,
        temperature=0.8,
    )
    summary = response.choices[0].message.content
    return summary

# %%
def critique_tool(summary):
    messages = [
        {"role": "system", "content": "You are an AI research assistant acting as a critique"},
        {"role": "user", "content": f"Please critique the following summary:\n\n{summary}. Recognize flaws within the summary, offer constructive criticism, and pinpoint areas for improvement"}
    ]
    response = client.chat.completions.create(
        model=model_name,
        messages=messages,
        max_tokens=500,
        stop=None,
        temperature=0.7,
    )
    critique = response.choices[0].message.content
    return critique

# %%
def final_summary_after_critique(summary, critique):
    messages = [
        {"role": "system", "content": "You are an Ai assistant conducting research"},
        {"role": "user", "content": f"Enhance the provided summary: {summary} in accordance with the ensuing evaluation: {critique}."}
    ]
    response = client.chat.completions.create(
        model=model_name,
        messages=messages,
        max_tokens=500,
        stop=None,
        temperature=0.7,
    )
    final_summary= response.choices[0].message.content
    return final_summary

# %%
def research_agent():

  topic_of_research = input("Welcome! I am your research assistant, ready to help you discover relevant topics and provide valuable summaries. Please enter your research topic::\n\n\n Research Topic: ")
  print("\n\n 1. Topic Breakdown Tool :")

  subqueries = topic_breakdown_tool(topic_of_research)
  print(f"\n {subqueries}")

  print("\n\n 2. Query Expansion Tool :")
  extended_subqueries = query_expansion_tool(subqueries)
  print(f"\n {extended_subqueries}")

  print("\n\n 3. Search Tool : ")
  search_results = search_tool(extended_subqueries)

  print(f"\n {search_results['hits']}")

  print("\n\n 4. Summary Tool :")
  summary = summary_tool(search_results['hits'])
  print(f"\n {summary}")

  print("\n\n 5. Critique Tool :")
  critic_results = critique_tool(summary)
  print(f"\n {critic_results}")

  print("\n\n 6. Final Summary Generator based on summary and crtique:")

  final_summary = final_summary_after_critique(summary, critic_results)
  print(f"\n {final_summary}")

# %%
research_agent()
# Out:
# Welcome! I am your research assistant, ready to help you discover relevant topics and provide valuable summaries. Please enter your research topic::
#
#
# Topic Of Research:Apple
#
#
#  1. Topic Breakdown Tool :
#
#  Here are 4 sub-queries based on the research topic "Apple":
#
# 1. **History of Apple Inc.**: What were the key events and milestones in the development of Apple as a company, and how did they contribute to its current status as a technology leader?
#
# 2. **Health Benefits of Apples**: What are the nutritional benefits of consuming apples, and how do they impact human health, including potential effects on chronic diseases such as heart disease, diabetes, and cancer?
#
# 3. **Apple Product Innovation**: How has Apple's approach to product design and innovation contributed to the success of its devices, such as the iPhone, iPad, and MacBook, and what role do features like user experience and ecosystem play in driving customer loyalty?
#
# 4. **Sustainability of Apple Production**: What are the environmental and social impacts of large-scale apple production, including factors such as water usage, pesticide application, and labor practices, and how can these be mitigated to promote more sustainable apple production practices?
#
#
#  2. Query Expansion Tool :
#
#  Here are the 4 sub-queries with keywords, synonyms, and phrases:
#
# 1. **History of Apple Inc.**
#    - {'Subquery':'History of Apple Inc.',
#      'Keywords':['Apple', 'History', 'Technology', ('Steve Jobs', 'Steve Wozniak'), 'Innovation'],
#      'Synonyms':['Background', 'Evolution', 'Development', 'Founders', 'Advancements'],
#      'Phrases':['Apple company history', 'Founding of Apple', 'Major milestones of Apple', 'Apple technological advancements', 'Influence of Steve Jobs on Apple']}
#
# 2. **Health Benefits of Apples**
#    - {'Subquery':'Health Benefits of Apples',
#      'Keywords':['Apples', 'Nutrition', 'Health', 'Benefits', ('Diet', 'Wellness')],
#      'Synonyms':['Advantages', 'Nutritional value', 'Wellbeing', 'Dietary benefits', 'Wholesome effects'],
#      'Phrases':['Apple health benefits', 'Nutritional value of apples', 'Apples and chronic disease prevention', 'Benefits of eating apples daily', 'Apple nutrition facts']}
#
# 3. **Apple Product Innovation**
#    - {'Subquery':'Apple Product Innovation',
#      'Keywords':['Apple', 'Innovation', 'Product design', ('User experience', 'UX'), ('iPhone', 'iPad', 'MacBook')],
#      'Synonyms':['Creativity', 'Technological advancements', 'Device development', 'Customer satisfaction', 'Product ecosystem'],
#      'Phrases':['Apple product design', 'Innovative Apple products', 'Role of user experience in Apple devices', 'Apple ecosystem and customer loyalty', 'Impact of Apple innovation on the tech industry']}
#
# 4. **Sustainability of Apple Production**
#    - {'Subquery':'Sustainability of Apple Production',
#      'Keywords':['Apple production', 'Sustainability', ('Environment', 'Environmental impact'), ('Social responsibility', 'Labor practices')],
#      'Synonyms':['Eco-friendliness', 'Green production', 'Social sustainability', 'Responsible farming', 'Conservation'],
#      'Phrases':['Sustainable apple farming', 'Environmental impact of apple production', 'Social responsibility in the apple industry', 'Apple production and water conservation', 'Mitigating the environmental effects of large-scale apple production']}
#
#
#  3. Search Tool :
#
#  [{'description': 'Compiled by specialists in Business Reference Services at the Library of Congress, this guide highlights stories about the people, places, and events that made their mark on business history.', 'snippets': ['Gulnar Nagashybayeva, Business Reference Specialist, Science, Technology & Business Division ... Carol Highsmith, photographer. Passersby outside an Apple computer store in the Washington, D.C. suburb of Bethesda, Maryland. 2015. Library of Congress Prints and Photographs Division. Apple Computer, Inc. was founded on April 1, 1976, by college dropouts Steve Jobs and Steve Wozniak, who brought to the new company a vision of changing the way people viewed computers.', 'It is also for the millions of Apple users, admirers, fans, and critics who may be curious about the origins of the products and the brand they feel so deeply about. Here is the story of the most amazing creative journey, which had to overcome tremendous opposition, both inside Apple and across the wider technology industry. Leading Apple with Steve Jobs: Management Lessons from a Controversial Genius by Jay Elliot', "His stories explain the symbiotic relationship between software and product development for those who have never dreamed of programming a computer, and reveal what it was like to work on the cutting edge of technology at one of the world's most admired companies. Keep It Simple: the Early Design Years of Apple by Hartmut Esslinger ... This book tells the story of Apple's evolution from the inside and its initial conception, when Steve was first driven by the power of design to establish it as the strategic core of Apple's business model.", "His tale is instructive and cautionary, filled with lessons about innovation, character, leadership, and values.--From publisher's description ... Computer geniuses who've made it big are the ultimate heroes for many kids. These young millionaires in the high-tech and business worlds are big news today, but like all inventors before them, their work is based on the work of their predecessors.A child of the 60s, Steve Jobs traveled around the globe in an attempt to find himself."], 'title': 'The Founding of Apple Computer, Inc. - This Month in Business History - Research Guides at Library of Congress', 'url': 'https://guides.loc.gov/this-month-in-business-history/april/apple-computer-founded'}, {'description': "Apple Inc., originally Apple Computer, Inc., is a multinational corporation that creates and markets consumer electronics and attendant computer software, and is a digital distributor of media content. Apple's core product lines are the iPhone smartphone, iPad tablet computer, and the Mac personal ...", 'snippets': ["Apple's core product lines are the iPhone smartphone, iPad tablet computer, and the Mac personal computer. The company offers its products online and has a chain of retail stores known as Apple Stores. Founders Steve Jobs, Steve Wozniak, and Ronald Wayne created Apple Computer Co.", 'On April 1, 1976, Apple Computer Company was founded by Steve Jobs, Steve Wozniak, and Ronald Wayne. The company was registered as a California business partnership. Wayne, who worked at Atari, Inc. as a chief draftsman, became a co-founder in return for a 10% stake.', 'Wozniak\'s first venture after leaving Apple was founding CL 9 in 1985 and creating the first programmable universal remote control two years later, called the "CORE", stating that "I never felt like I was turning my back on my own company [Apple]." He told Apple\'s director of engineering Wayne Rosing about his decision to step away from the company, but not his longtime business partner and friend Steve Jobs.', 'By 1972, Jobs had withdrawn from Reed College and Wozniak from UC Berkeley. Wozniak designed a video terminal that he could use to log on to the minicomputers at Call Computer. Alex Kamradt commissioned the design and sold a small number of them through his firm. Aside from their interest in up-to-date technology, the ...
#
#
#  4. Summary Tool :
#
#  The search results provide a comprehensive overview of the history of Apple Inc., its founders, and their contributions to the technology industry. Here is a summary of the key points:
#
# **Founding of Apple Inc.**
#
# * Apple Inc. was founded on April 1, 1976, by Steve Jobs, Steve Wozniak, and Ronald Wayne as a partnership.
# * The company's first product was the Apple I, a computer designed and hand-built entirely by Wozniak.
# * Jobs and Wozniak started the business in Jobs' garage, and the first generation of the Apple I was initially sold without a monitor, keyboard, or casing for $666.66.
#
# **Early Years and Innovation**
#
# * In 1977, Apple introduced the Apple II, one of the first highly successful mass-produced personal computers.
# * The Apple II revolutionized the computer industry with the introduction of the first-ever color graphics.
# * In 1980, Apple went public, making its founders multi-millionaires.
# * The company introduced the Macintosh computer in 1984, which featured a graphical user interface (GUI) and was navigable by computer mouse.
#
# **Steve Jobs and Steve Wozniak**
#
# * Steve Jobs and Steve Wozniak are credited with inventing the first true personal computer, which changed people's ideas of what a computer could look like and what it could do to make their lives easier and their work more efficient.
# * Wozniak was inducted into the Inventors Hall of Fame in 2000 and is a past recipient of the Heinz Award for Technology, The Economy, and Employment.
# * Jobs was granted the Jefferson Award for Public Service in 1987 and was named Entrepreneur of the Decade by Inc. Magazine in 1989.
#
# **Challenges and Departure**
#
# * In 1985, Jobs was stripped of his operational duties at Apple after a power struggle with then-CEO John Sculley.
# * Wozniak had also quit his active employment at Apple earlier in 1985 to pursue other ventures, expressing his frustration with Apple's treatment of the Apple II division.
# * Jobs resigned from Apple in September 1985 and took several Apple employees with him to found NeXT.
#
# **Return to Apple and Legacy**
#
# * In 1996, Apple acquired NeXT, and Jobs returned to the company he co-founded.
# * Under Jobs' leadership, Apple introduced innovative products such as the iPod, iPhone, and iPad
#
#
#  5. Critique Tool :
#
#  **Overall Assessment**
#
# The summary provides a good overview of the history of Apple Inc., its founders, and their contributions to the technology industry. However, there are areas that can be improved to make the summary more comprehensive, accurate, and engaging.
#
# **Constructive Criticism**
#
# 1. **Lack of clarity and concision**: Some sentences are wordy and could be broken up for better clarity. For example, the first sentence under "Steve Jobs and Steve Wozniak" is a long, convoluted sentence that could be split into two or three shorter sentences.
# 2. **Inconsistent formatting**: The summary uses both bullet points and paragraphs. To improve readability, consider using bullet points consistently throughout the summary or using paragraphs with clear headings.
# 3. **Limited context**: The summary could benefit from more context about the historical period in which Apple was founded and the impact of the company's innovations on the technology industry. For example, the summary could mention the state of the computer industry in the 1970s and how Apple's products changed the landscape.
# 4. **Overemphasis on Jobs and Wozniak**: While Steve Jobs and Steve Wozniak are certainly important figures in Apple's history, the summary could benefit from more information about other key players, such as Ronald Wayne, John Sculley, and Tim Cook.
# 5. **Lack of analysis**: The summary primarily provides a factual account of Apple's history without analyzing the significance of the company's innovations or the impact of its products on society.
# 6. **No clear conclusion**: The summary ends abruptly without summarizing the main points or providing a final thought on Apple's legacy.
#
# **Specific Errors and Inconsistencies**
#
# 1. **Date inconsistency**: The summary states that Apple was founded on April 1, 1976, but does not mention that the company was originally named Apple Computer, Inc. and was renamed Apple Inc. in 2007.
# 2. **Inaccurate pricing**: The summary states that the Apple I was sold for $666.66, but does not mention that this price was for the bare circuit board, and that customers had to add their own keyboard, monitor, and casing.
# 3. **Missing information**: The summary does not mention the significance of the Apple II's introduction of the first-ever color graphics or the impact of the Macintosh computer on the industry.
#
# **Recommendations for Improvement**
#
# 1. **Add more context**: Provide more information about the historical
#
#
#  6. Final Summary Generator based on summary and crtique:
#
#  **Enhanced Summary: The History of Apple Inc. and Its Founders**
#
# The search results provide a comprehensive overview of the history of Apple Inc., its founders, and their significant contributions to the technology industry. This summary highlights the key points in the company's history, from its founding to its current status as a global leader in innovation.
#
# **Founding of Apple Inc.**
#
# * April 1, 1976: Apple Inc. was founded by Steve Jobs, Steve Wozniak, and Ronald Wayne as a partnership, initially named Apple Computer, Inc.
# * The company's first product was the Apple I, a computer designed and hand-built entirely by Wozniak, which was sold without a monitor, keyboard, or casing for $666.66.
# * Jobs and Wozniak started the business in Jobs' garage, marking the beginning of a revolutionary journey in the technology industry.
#
# **Early Years and Innovation**
#
# * 1977: Apple introduced the Apple II, one of the first highly successful mass-produced personal computers, which revolutionized the industry with the introduction of the first-ever color graphics.
# * 1980: Apple went public, making its founders multi-millionaires and paving the way for future innovations.
# * 1984: The company introduced the Macintosh computer, featuring a graphical user interface (GUI) and navigable by computer mouse, which further transformed the industry.
#
# **Steve Jobs and Steve Wozniak: Visionary Founders**
#
# * Steve Jobs and Steve Wozniak are credited with inventing the first true personal computer, which changed people's perceptions of what a computer could look like and what it could do to make their lives easier and their work more efficient.
# * Wozniak was inducted into the Inventors Hall of Fame in 2000 and is a past recipient of the Heinz Award for Technology, The Economy, and Employment, recognizing his significant contributions to the field.
# * Jobs was granted the Jefferson Award for Public Service in 1987 and was named Entrepreneur of the Decade by Inc. Magazine in 1989, acknowledging his innovative spirit and leadership.
#
# **Challenges and Departure**
#
# * 1985: Jobs was stripped of his operational duties at Apple after a power struggle with then-CEO John Sculley, leading to his resignation from the company in September 1985.
# * Wozniak had also quit his active employment at Apple earlier in 1985 to pursue other ventures, expressing
